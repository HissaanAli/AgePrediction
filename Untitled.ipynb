# %% [markdown]
# # IMPORTS

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

from PIL import Image
import numpy as np
import pandas as pd
import os
TRAIN_PATH = "dataset/training_set/"
VAL_PATH = "dataset/validation_set/"
TEST_PATH = "dataset/test_set/"

# %%
# DATA LOADER

def load_into_df(path):
    data = {
        'path': [],
        'age': []
           }
    file_names = os.listdir(path)
    for file in file_names:
        data['age'].append(int(file.split('/')[-1].split('_')[0]))
        data['path'].append(file)
    df = pd.DataFrame(data)
    return df
class Item:
    def __init__(self, path):
        self._image = np.array(Image.open(path))
        self._age = int(path.split('/')[-1].split('_')[0])
    def get_image(self):
        return self._image
    def get_age(self):
        return self._age

# %%
df = load_into_df(TRAIN_PATH)
df
# Out:
#                            path  age
# 0     001_20161219140525218.jpg    1
# 1     001_20161219140744200.jpg    1
# 2     001_20161219140803696.jpg    1
# 3     001_20161219140952943.jpg    1
# 4     001_20161219141431352.jpg    1
# ...                         ...  ...
# 5395  080_20170117175507859.jpg   80
# 5396  080_20170117175604677.jpg   80
# 5397  080_20170117204632601.jpg   80
# 5398  080_20170120222314991.jpg   80
# 5399  080_20170120223552933.jpg   80
#
# [5400 rows x 2 columns]

# %%
item = Item("dataset/training_set/034_20170117121730983.jpg")
plt.imshow(item.get_image())
print(item.get_age())
# Out:
# 34

# %% [markdown]
# # PRE PROCESSING
