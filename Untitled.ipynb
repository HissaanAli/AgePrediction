# %% [markdown]
# # IMPORTS

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras import datasets, layers, models, losses
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

from PIL import Image
import numpy as np
import pandas as pd
import os

# %%
TRAIN_PATH = "dataset/training_set/"
VAL_PATH = "dataset/validation_set/"
TEST_PATH = "dataset/test_set/"

def imshow(img):
    plt.imshow(img, cmap = 'gray')
def gray_to_rgb(img):
    return tf.image.grayscale_to_rgb(tf.convert_to_tensor(img.reshape(91,91,1)))
def resize(img):
    return tf.image.resize(img, [224,224], method='nearest').numpy()

# %% [markdown]
# # DATA LOADER

# %%
def load_into_df(path):
    data = {
        'path': [],
        'age': []
           }
    file_names = os.listdir(path)
    for file in file_names:
        data['age'].append(int(file.split('/')[-1].split('_')[0]))
        data['path'].append(file)
    df = pd.DataFrame(data)
    return df
class Item:
    def __init__(self, path):
        self._image = np.array(Image.open(path))
        self._age = int(path.split('/')[-1].split('_')[0])
    def get_image(self):
        return self._image
    def get_age(self):
        return self._age

# %%
train_df = load_into_df(TRAIN_PATH)
print('train_df:')
display(train_df.describe())
val_df = load_into_df(VAL_PATH)
print('val_df:')
display(val_df.describe())
test_df = load_into_df(TEST_PATH)
print('test_df:')
display(test_df.describe())
# Out:
# train_df:
#                age
# count  5400.000000
# mean     32.030185
# std      18.231843
# min       1.000000
# 25%      23.000000
# 50%      29.000000
# 75%      42.000000
# max      80.000000
# val_df:
#                age
# count  2315.000000
# mean     32.020302
# std      18.229641
# min       1.000000
# 25%      23.000000
# 50%      29.000000
# 75%      42.000000
# max      80.000000
# test_df:
#                age
# count  1159.000000
# mean     32.000000
# std      18.223663
# min       1.000000
# 25%      23.000000
# 50%      29.000000
# 75%      42.000000
# max      80.000000

# %% [markdown]
# # DATA VISUALIZATION

# %%
def plot_counts(df):
    plt.rcParams["figure.figsize"] = (30,15)
    sns.countplot(data = df, x = 'age')
    plt.rcParams["figure.figsize"] = (5,5)
plot_counts(train_df)
#plot_counts(test_df)

# %% [markdown]
# # DATA PREPARATION

# %%
def get_xy(path):
    file_names = os.listdir(path)
    items = []
    for file in file_names:
        item = Item(path+file)
        items.append(item)
    #x = np.array([resize(gray_to_rgb(item.get_image())) for item in items])
    x = np.array([item.get_image().flatten() for item in items])
    y = np.array([item.get_age() for item in items])
    return x, y

# %%
x_train, y_train = get_xy(TRAIN_PATH)
x_val, y_val = get_xy(VAL_PATH)
x_test, y_test = get_xy(TEST_PATH)

print('training:',x_train.shape, y_train.shape)
print('validation:',x_val.shape, y_val.shape)
print('test:',x_test.shape, y_test.shape)
# Out:
# training: (5400, 8281) (5400,)
# validation: (2315, 8281) (2315,)
# test: (1159, 8281) (1159,)

# %% [markdown]
# # PRE PROCESSING

# %%
# NORMALIZATION

def normalize(x):
    return x/255
x_train = normalize(x_train)
x_val = normalize(x_val)
x_test = normalize(x_test)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42, k_neighbors = 4)
x_train_new, y_train_new = sm.fit_resample(x_train, y_train)
x_train_new = np.array([x.reshape(-1,1).reshape(91,91, 1) for x in x_train_new])

# %%
x_val = x_val.reshape(x_val.shape[0], 91, 91,1)
x_test = x_test.reshape(x_test.shape[0], 91, 91,1)
print(x_val.shape)
print(x_test.shape)
# Out:
# (2315, 91, 91, 1)
# (1159, 91, 91, 1)

# %%
import random as r
plt.imshow(x_train_new[r.randint(1,40000)].reshape(91,91), cmap = 'gray')

# %%
from tensorflow.keras.applications import ResNet50

#base_model = ResNet50(input_shape=(224, 224, 3), include_top=False, weights="imagenet")
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, GlobalAveragePooling2D, AveragePooling2D, BatchNormalization, Dropout, Input, Conv2D

# %%
res_model = ResNet50(include_top=False, weights='imagenet', input_shape=(224, 224, 3))#, input_tensor=Input(shape=(224, 224, 3)))

for layer in res_model.layers[:]:
    layer.trainable = False

model = res_model.output
#model = Conv2D(256, (7,7), padding = 'same', activation = 'relu')(model)
model = AveragePooling2D(pool_size = (3,3))(model)
model = BatchNormalization(name="batch_norm_1")(model)
model = Flatten(name="flatten")(model)
model = Dense(512, activation="relu")(model)
model = Dropout(0.3)(model)
model = BatchNormalization(name="batch_norm_2")(model)
#model = Dense(256, activation="relu")(model)
#model = Dropout(0.3)(model)
#model = BatchNormalization(name="batch_norm_3")(model)
#model = Dense(128, activation="relu")(model)
#model = Dropout(0.4)(model)
#model = BatchNormalization(name="batch_norm_4")(model)
#model = Dense(64, activation="relu")(model)
#model = Dropout(0.4)(model)
model = Dense(1, activation="linear")(model)


model = Model(inputs=res_model.input, outputs=model)
model.summary()
# Out:
# Model: "functional_15"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 230, 230, 3)  0           input_11[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 112, 112, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 112, 112, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 112, 112, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 114, 114, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 56, 56, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 56, 56, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 56, 56, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 56, 56, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 56, 56, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 56, 56, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 56, 56, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 56, 56, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 56, 56, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 56, 56, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 56, 56, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 56, 56, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 56, 56, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 56, 56, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 56, 56, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 56, 56, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 56, 56, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 56, 56, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 56, 56, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 56, 56, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 28, 28, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 28, 28, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 28, 28, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 28, 28, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 28, 28, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 28, 28, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 28, 28, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 28, 28, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 28, 28, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 28, 28, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 28, 28, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 28, 28, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 28, 28, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 28, 28, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 28, 28, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 28, 28, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 28, 28, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 28, 28, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 28, 28, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 28, 28, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 28, 28, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 28, 28, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 28, 28, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 14, 14, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 14, 14, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 14, 14, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 14, 14, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 14, 14, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 14, 14, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 14, 14, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 14, 14, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 14, 14, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 14, 14, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 14, 14, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 14, 14, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 14, 14, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 14, 14, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 14, 14, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 14, 14, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 14, 14, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 14, 14, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 14, 14, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 14, 14, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 14, 14, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 14, 14, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 14, 14, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 14, 14, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 14, 14, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 14, 14, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 14, 14, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 14, 14, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 14, 14, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 14, 14, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 7, 7, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 7, 7, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 7, 7, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 7, 7, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 7, 7, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 7, 7, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 7, 7, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 7, 7, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 7, 7, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 7, 7, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 7, 7, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 7, 7, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 7, 7, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 7, 7, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 7, 7, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 7, 7, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 7, 7, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 7, 7, 2048)   0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 2, 2, 2048)   0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# batch_norm_1 (BatchNormalizatio (None, 2, 2, 2048)   8192        average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 8192)         0           batch_norm_1[0][0]
# __________________________________________________________________________________________________
# dense_31 (Dense)                (None, 512)          4194816     flatten[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 512)          0           dense_31[0][0]
# __________________________________________________________________________________________________
# batch_norm_2 (BatchNormalizatio (None, 512)          2048        dropout_22[0][0]
# __________________________________________________________________________________________________
# dense_32 (Dense)                (None, 1)            513         batch_norm_2[0][0]
# ==================================================================================================
# Total params: 27,793,281
# Trainable params: 4,200,449
# Non-trainable params: 23,592,832
# __________________________________________________________________________________________________

# %%
model.compile(loss='mean_absolute_error',
              optimizer=tf.keras.optimizers.Adam(), 
              metrics=[tf.keras.metrics.MeanAbsoluteError()]
             )

# %%
history = model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 100)
# Out:
# Epoch 1/100
# 169/169 [==============================] - 80s 475ms/step - loss: 24.4920 - mean_absolute_error: 24.4920 - val_loss: 25.4455 - val_mean_absolute_error: 25.4455
# Epoch 2/100
# 169/169 [==============================] - 19s 113ms/step - loss: 13.2458 - mean_absolute_error: 13.2458 - val_loss: 21.0133 - val_mean_absolute_error: 21.0133
# Epoch 3/100
# 169/169 [==============================] - 19s 112ms/step - loss: 13.2891 - mean_absolute_error: 13.2891 - val_loss: 14.4668 - val_mean_absolute_error: 14.4668
# Epoch 4/100
# 169/169 [==============================] - 19s 115ms/step - loss: 13.2439 - mean_absolute_error: 13.2439 - val_loss: 13.5803 - val_mean_absolute_error: 13.5803
# Epoch 5/100
# 169/169 [==============================] - 20s 116ms/step - loss: 13.2939 - mean_absolute_error: 13.2939 - val_loss: 13.2701 - val_mean_absolute_error: 13.2701
# Epoch 6/100
# 169/169 [==============================] - 19s 114ms/step - loss: 13.2073 - mean_absolute_error: 13.2073 - val_loss: 13.1781 - val_mean_absolute_error: 13.1781
# Epoch 7/100
# 169/169 [==============================] - 19s 113ms/step - loss: 12.9586 - mean_absolute_error: 12.9586 - val_loss: 13.8815 - val_mean_absolute_error: 13.8815
# Epoch 8/100
# 169/169 [==============================] - 19s 113ms/step - loss: 12.9406 - mean_absolute_error: 12.9406 - val_loss: 13.3705 - val_mean_absolute_error: 13.3705
# Epoch 9/100
# 169/169 [==============================] - 19s 114ms/step - loss: 12.6639 - mean_absolute_error: 12.6639 - val_loss: 13.0483 - val_mean_absolute_error: 13.0483
# Epoch 10/100
# 169/169 [==============================] - 19s 114ms/step - loss: 12.3685 - mean_absolute_error: 12.3685 - val_loss: 12.5021 - val_mean_absolute_error: 12.5021
# Epoch 11/100
# 169/169 [==============================] - 19s 113ms/step - loss: 12.4228 - mean_absolute_error: 12.4228 - val_loss: 12.6187 - val_mean_absolute_error: 12.6187
# Epoch 12/100
# 169/169 [==============================] - 19s 113ms/step - loss: 12.5246 - mean_absolute_error: 12.5246 - val_loss: 14.2486 - val_mean_absolute_error: 14.2486
# Epoch 13/100
# 169/169 [==============================] - 19s 113ms/step - loss: 12.1151 - mean_absolute_error: 12.1151 - val_loss: 12.9560 - val_mean_absolute_error: 12.9560
# Epoch 14/100
# 169/169 [==============================] - 19s 113ms/step - loss: 12.2130 - mean_absolute_error: 12.2130 - val_loss: 13.0502 - val_mean_absolute_error: 13.0502
# Epoch 15/100
# 169/169 [==============================] - 19s 113ms/step - loss: 12.2972 - mean_absolute_error: 12.2972 - val_loss: 12.8096 - val_mean_absolute_error: 12.8096
# Epoch 16/100
# 169/169 [==============================] - 19s 114ms/step - loss: 11.8249 - mean_absolute_error: 11.8249 - val_loss: 12.1913 - val_mean_absolute_error: 12.1913
# Epoch 17/100
# 169/169 [==============================] - 19s 114ms/step - loss: 11.4473 - mean_absolute_error: 11.4473 - val_loss: 12.4484 - val_mean_absolute_error: 12.4484
# Epoch 18/100
# 169/169 [==============================] - 19s 113ms/step - loss: 11.1831 - mean_absolute_error: 11.1831 - val_loss: 11.7763 - val_mean_absolute_error: 11.7763
# Epoch 19/100
# 169/169 [==============================] - 19s 115ms/step - loss: 11.2322 - mean_absolute_error: 11.2322 - val_loss: 10.9874 - val_mean_absolute_error: 10.9874
# Epoch 20/100
# 169/169 [==============================] - 19s 115ms/step - loss: 11.3422 - mean_absolute_error: 11.3422 - val_loss: 14.9141 - val_mean_absolute_error: 14.9141
# Epoch 21/100
# 169/169 [==============================] - 19s 115ms/step - loss: 12.4672 - mean_absolute_error: 12.4672 - val_loss: 12.6375 - val_mean_absolute_error: 12.6375
# Epoch 22/100
# 169/169 [==============================] - 19s 113ms/step - loss: 11.9047 - mean_absolute_error: 11.9047 - val_loss: 12.6498 - val_mean_absolute_error: 12.6498
# Epoch 23/100
# 169/169 [==============================] - 19s 113ms/step - loss: 11.6707 - mean_absolute_error: 11.6707 - val_loss: 11.6536 - val_mean_absolute_error: 11.6536
# Epoch 24/100
# 169/169 [==============================] - 19s 113ms/step - loss: 11.7357 - mean_absolute_error: 11.7357 - val_loss: 12.9947 - val_mean_absolute_error: 12.9947
# Epoch 25/100
# 169/169 [==============================] - 19s 112ms/step - loss: 12.7123 - mean_absolute_error: 12.7123 - val_loss: 12.7326 - val_mean_absolute_error: 12.7326
# Epoch 26/100
# 169/169 [==============================] - 19s 112ms/step - loss: 12.3015 - mean_absolute_error: 12.3015 - val_loss: 14.0614 - val_mean_absolute_error: 14.0614
# Epoch 27/100
# 169/169 [==============================] - 19s 113ms/step - loss: 12.2887 - mean_absolute_error: 12.2887 - val_loss: 12.6731 - val_mean_absolute_error: 12.6731
# Epoch 28/100
# 169/169 [==============================] - 19s 114ms/step - loss: 12.3670 - mean_absolute_error: 12.3670 - val_loss: 17.3549 - val_mean_absolute_error: 17.3549
# Epoch 29/100
#  13/169 [=>............................] - ETA: 11s - loss: 13.3199 - mean_absolute_error: 13.3199
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-9f33ce8a7432> in <module>
# ----> 1 history = model.fit(x_train, y_train, validation_data = (x_val, y_val), epochs = 100)
#
# E:\Anaconda_New\envs\first_env\lib\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# E:\Anaconda_New\envs\first_env\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# E:\Anaconda_New\envs\first_env\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# E:\Anaconda_New\envs\first_env\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# E:\Anaconda_New\envs\first_env\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# E:\Anaconda_New\envs\first_env\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1841       `args` and `kwargs`.
#    1842     """
# -> 1843     return self._call_flat(
#    1844         [t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1845          if isinstance(t, (ops.Tensor,
#
# E:\Anaconda_New\envs\first_env\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1921         and executing_eagerly):
#    1922       # No tape is watching; skip to running the function.
# -> 1923       return self._build_call_outputs(self._inference_function.call(
#    1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#
# E:\Anaconda_New\envs\first_env\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543       with _InterpolateFunctionError(self):
#     544         if cancellation_manager is None:
# --> 545           outputs = execute.execute(
#     546               str(self.signature.name),
#     547               num_outputs=self._num_outputs,
#
# E:\Anaconda_New\envs\first_env\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
plt.rcParams["figure.figsize"] = (10,10)
loss = history.history["loss"]
val_loss = history.history["val_loss"]
plt.plot(loss, label = 'loss')
plt.plot(val_loss, label = 'val_loss')

# %%
model.evaluate(x_test, y_test)
# Out:
# 37/37 [==============================] - 3s 82ms/step - loss: 9.1083 - mean_absolute_error: 9.1083
# [9.108264923095703, 9.108264923095703]

# %%
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Dropout
from keras.layers.core import Lambda
from keras.layers.core import Dense
from keras.layers import Flatten
from keras.layers import Input
import tensorflow as tf

class UtkMultiOutputModel():
    """
    Used to generate our multi-output model. This CNN contains three branches, one for age, other for 
    sex and another for race. Each branch contains a sequence of Convolutional Layers that is defined
    on the make_default_hidden_layers method.
    """
    def make_default_hidden_layers(self, inputs):
        """
        Used to generate a default set of hidden layers. The structure used in this network is defined as:
        
        Conv2D -> BatchNormalization -> Pooling -> Dropout
        """
        x = Conv2D(16, (3, 3), padding="same")(inputs)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(3, 3))(x)
        x = Dropout(0.25)(x)

        x = Conv2D(32, (3, 3), padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        x = Dropout(0.25)(x)

        x = Conv2D(32, (3, 3), padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        x = Dropout(0.25)(x)
        
        x = Conv2D(64, (3, 3), padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        x = Dropout(0.25)(x)
        
        x = Conv2D(128, (3, 3), padding="same")(x)
        x = Activation("relu")(x)
        x = BatchNormalization(axis=-1)(x)
        x = MaxPooling2D(pool_size=(2, 2))(x)
        x = Dropout(0.35)(x)
        
        #x = Conv2D(128, (3, 3), padding="same")(x)
        #x = Activation("relu")(x)
        #x = BatchNormalization(axis=-1)(x)
        #x = MaxPooling2D(pool_size=(2, 2))(x)
        #x = Dropout(0.35)(x)
        return x


    def build_age_branch(self, inputs):   
        """
        Used to build the age branch of our face recognition network.
        This branch is composed of three Conv -> BN -> Pool -> Dropout blocks, 
        followed by the Dense output layer.

        """
        x = self.make_default_hidden_layers(inputs)

        x = Flatten()(x)
        x = Dense(256)(x)
        x = Activation("relu")(x)
        x = BatchNormalization()(x)
        x = Dropout(0.5)(x)
        x = Dense(1)(x)
        x = Activation("linear", name="age_output")(x)

        return x

    def assemble_full_model(self, width, height):
        """
        Used to assemble our multi-output model CNN.
        """
        input_shape = (height, width, 1)

        inputs = Input(shape=input_shape)

        age_branch = self.build_age_branch(inputs)
        

        model = Model(inputs=inputs,
                     outputs = [age_branch],
                     name="face_net")

        return model
mod = UtkMultiOutputModel().assemble_full_model(91, 91)

# %%
from keras.optimizers import Adam

init_lr = 1.2e-4
epochs = 400

opt = tf.keras.optimizers.Adam(lr=init_lr, decay=init_lr / epochs)

mod.compile(loss='mean_absolute_error',
              optimizer=opt, 
              metrics=[tf.keras.metrics.MeanAbsoluteError()]
             )
mod.summary()

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
      rotation_range=5,
      width_shift_range=0.05,
      height_shift_range=0.05,
      shear_range=0.05,
      zoom_range=0.05,
      horizontal_flip=True,
      vertical_flip=False,
      fill_mode='nearest')

# %%
train_generator = train_datagen.flow(
        x_train,
        y_train,
        batch_size=16)

# %%
history = mod.fit(x_train_new, y_train_new, validation_data = (x_val, y_val), epochs = epochs)
# Out:
# Epoch 1/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 38.3430 - mean_absolute_error: 38.3430 - val_loss: 24.3687 - val_mean_absolute_error: 24.3687
# Epoch 2/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 27.5175 - mean_absolute_error: 27.5175 - val_loss: 16.6697 - val_mean_absolute_error: 16.6697
# Epoch 3/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 14.8426 - mean_absolute_error: 14.8426 - val_loss: 17.8830 - val_mean_absolute_error: 17.8830
# Epoch 4/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 12.1585 - mean_absolute_error: 12.1585 - val_loss: 19.0149 - val_mean_absolute_error: 19.0149
# Epoch 5/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 11.3833 - mean_absolute_error: 11.3833 - val_loss: 13.6459 - val_mean_absolute_error: 13.6459
# Epoch 6/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 10.9317 - mean_absolute_error: 10.9317 - val_loss: 18.2634 - val_mean_absolute_error: 18.2634
# Epoch 7/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 10.5432 - mean_absolute_error: 10.5432 - val_loss: 9.2127 - val_mean_absolute_error: 9.2127
# Epoch 8/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 10.2640 - mean_absolute_error: 10.2640 - val_loss: 10.0153 - val_mean_absolute_error: 10.0153loss: 10.2668 - mean_absolute_error: 10.
# Epoch 9/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 9.9547 - mean_absolute_error: 9.9547 - val_loss: 9.5997 - val_mean_absolute_error: 9.5997
# Epoch 10/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 9.7117 - mean_absolute_error: 9.7117 - val_loss: 8.3026 - val_mean_absolute_error: 8.3026
# Epoch 11/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 9.5653 - mean_absolute_error: 9.5653 - val_loss: 8.9757 - val_mean_absolute_error: 8.9757
# Epoch 12/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 9.2841 - mean_absolute_error: 9.2841 - val_loss: 10.2073 - val_mean_absolute_error: 10.2073
# Epoch 13/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 9.1190 - mean_absolute_error: 9.1190 - val_loss: 9.8748 - val_mean_absolute_error: 9.8748
# Epoch 14/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 8.9704 - mean_absolute_error: 8.9704 - val_loss: 10.0634 - val_mean_absolute_error: 10.0634
# Epoch 15/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 8.8685 - mean_absolute_error: 8.8685 - val_loss: 12.8627 - val_mean_absolute_error: 12.8627
# Epoch 16/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 8.6685 - mean_absolute_error: 8.6685 - val_loss: 11.2802 - val_mean_absolute_error: 11.2802 1s - loss: 8.6939 - m
# Epoch 17/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 8.4791 - mean_absolute_error: 8.4791 - val_loss: 9.2478 - val_mean_absolute_error: 9.2478
# Epoch 18/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 8.4903 - mean_absolute_error: 8.4903 - val_loss: 8.6561 - val_mean_absolute_error: 8.6561
# Epoch 19/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 8.2966 - mean_absolute_error: 8.2966 - val_loss: 8.8906 - val_mean_absolute_error: 8.8906
# Epoch 20/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 8.2572 - mean_absolute_error: 8.2572 - val_loss: 7.6348 - val_mean_absolute_error: 7.6348
# Epoch 21/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 8.1828 - mean_absolute_error: 8.1828 - val_loss: 8.9997 - val_mean_absolute_error: 8.9997
# Epoch 22/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 8.0276 - mean_absolute_error: 8.0276 - val_loss: 7.6914 - val_mean_absolute_error: 7.6914
# Epoch 23/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 8.0037 - mean_absolute_error: 8.0037 - val_loss: 7.8295 - val_mean_absolute_error: 7.8295
# Epoch 24/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.8741 - mean_absolute_error: 7.8741 - val_loss: 7.2994 - val_mean_absolute_error: 7.2994
# Epoch 25/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.7959 - mean_absolute_error: 7.7959 - val_loss: 7.2058 - val_mean_absolute_error: 7.2058
# Epoch 26/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.7259 - mean_absolute_error: 7.7259 - val_loss: 9.6044 - val_mean_absolute_error: 9.6044
# Epoch 27/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.7160 - mean_absolute_error: 7.7160 - val_loss: 8.7035 - val_mean_absolute_error: 8.7035
# Epoch 28/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.6579 - mean_absolute_error: 7.6579 - val_loss: 7.9751 - val_mean_absolute_error: 7.9751
# Epoch 29/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.5988 - mean_absolute_error: 7.5988 - val_loss: 7.6004 - val_mean_absolute_error: 7.6004
# Epoch 30/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.4916 - mean_absolute_error: 7.4916 - val_loss: 8.0655 - val_mean_absolute_error: 8.0655
# Epoch 31/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.4731 - mean_absolute_error: 7.4731 - val_loss: 9.2351 - val_mean_absolute_error: 9.2351
# Epoch 32/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.4274 - mean_absolute_error: 7.4274 - val_loss: 8.3341 - val_mean_absolute_error: 8.3341
# Epoch 33/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.3091 - mean_absolute_error: 7.3091 - val_loss: 13.0745 - val_mean_absolute_error: 13.0745
# Epoch 34/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.2603 - mean_absolute_error: 7.2603 - val_loss: 10.5934 - val_mean_absolute_error: 10.5934
# Epoch 35/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.2541 - mean_absolute_error: 7.2541 - val_loss: 7.4826 - val_mean_absolute_error: 7.4826
# Epoch 36/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.1586 - mean_absolute_error: 7.1586 - val_loss: 7.9660 - val_mean_absolute_error: 7.9660
# Epoch 37/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 7.0985 - mean_absolute_error: 7.0985 - val_loss: 7.0017 - val_mean_absolute_error: 7.0017
# Epoch 38/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.0944 - mean_absolute_error: 7.0944 - val_loss: 6.9063 - val_mean_absolute_error: 6.9063
# Epoch 39/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.1065 - mean_absolute_error: 7.1065 - val_loss: 10.2646 - val_mean_absolute_error: 10.2646
# Epoch 40/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.0905 - mean_absolute_error: 7.0905 - val_loss: 7.0972 - val_mean_absolute_error: 7.0972
# Epoch 41/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 7.0505 - mean_absolute_error: 7.0505 - val_loss: 7.7645 - val_mean_absolute_error: 7.7645
# Epoch 42/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.9759 - mean_absolute_error: 6.9759 - val_loss: 10.0100 - val_mean_absolute_error: 10.0100
# Epoch 43/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.9410 - mean_absolute_error: 6.9410 - val_loss: 8.5736 - val_mean_absolute_error: 8.5736
# Epoch 44/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.9023 - mean_absolute_error: 6.9023 - val_loss: 7.3314 - val_mean_absolute_error: 7.3314
# Epoch 45/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.8718 - mean_absolute_error: 6.8718 - val_loss: 6.7666 - val_mean_absolute_error: 6.7666
# Epoch 46/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.8747 - mean_absolute_error: 6.8747 - val_loss: 6.7655 - val_mean_absolute_error: 6.7655
# Epoch 47/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.7864 - mean_absolute_error: 6.7864 - val_loss: 7.2120 - val_mean_absolute_error: 7.2120
# Epoch 48/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.8518 - mean_absolute_error: 6.8518 - val_loss: 10.5647 - val_mean_absolute_error: 10.5647
# Epoch 49/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.7685 - mean_absolute_error: 6.7685 - val_loss: 6.8348 - val_mean_absolute_error: 6.8348
# Epoch 50/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.7392 - mean_absolute_error: 6.7392 - val_loss: 7.0397 - val_mean_absolute_error: 7.0397
# Epoch 51/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.7427 - mean_absolute_error: 6.7427 - val_loss: 7.1915 - val_mean_absolute_error: 7.1915
# Epoch 52/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.7305 - mean_absolute_error: 6.7305 - val_loss: 11.5151 - val_mean_absolute_error: 11.5151
# Epoch 53/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.6078 - mean_absolute_error: 6.6078 - val_loss: 8.2610 - val_mean_absolute_error: 8.2610
# Epoch 54/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.6833 - mean_absolute_error: 6.6833 - val_loss: 7.7858 - val_mean_absolute_error: 7.7858
# Epoch 55/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.5432 - mean_absolute_error: 6.5432 - val_loss: 7.9460 - val_mean_absolute_error: 7.9460
# Epoch 56/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.6174 - mean_absolute_error: 6.6174 - val_loss: 7.6020 - val_mean_absolute_error: 7.6020
# Epoch 57/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.6676 - mean_absolute_error: 6.6676 - val_loss: 10.0686 - val_mean_absolute_error: 10.0686
# Epoch 58/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.6044 - mean_absolute_error: 6.6044 - val_loss: 9.4069 - val_mean_absolute_error: 9.4069
# Epoch 59/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.4914 - mean_absolute_error: 6.4914 - val_loss: 7.0998 - val_mean_absolute_error: 7.0998
# Epoch 60/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.5433 - mean_absolute_error: 6.5433 - val_loss: 11.4091 - val_mean_absolute_error: 11.4091
# Epoch 61/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.5125 - mean_absolute_error: 6.5125 - val_loss: 6.7386 - val_mean_absolute_error: 6.7386
# Epoch 62/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.4710 - mean_absolute_error: 6.4710 - val_loss: 6.7005 - val_mean_absolute_error: 6.7005
# Epoch 63/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.5127 - mean_absolute_error: 6.5127 - val_loss: 6.9881 - val_mean_absolute_error: 6.9881
# Epoch 64/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.4936 - mean_absolute_error: 6.4936 - val_loss: 7.3409 - val_mean_absolute_error: 7.3409
# Epoch 65/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.5413 - mean_absolute_error: 6.5413 - val_loss: 7.4963 - val_mean_absolute_error: 7.4963
# Epoch 66/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.4525 - mean_absolute_error: 6.4525 - val_loss: 6.7006 - val_mean_absolute_error: 6.7006
# Epoch 67/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.3790 - mean_absolute_error: 6.3790 - val_loss: 8.3370 - val_mean_absolute_error: 8.3370
# Epoch 68/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.3839 - mean_absolute_error: 6.3839 - val_loss: 6.6762 - val_mean_absolute_error: 6.6762
# Epoch 69/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.4700 - mean_absolute_error: 6.4700 - val_loss: 6.8203 - val_mean_absolute_error: 6.8203
# Epoch 70/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.3467 - mean_absolute_error: 6.3467 - val_loss: 6.9927 - val_mean_absolute_error: 6.9927
# Epoch 71/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.3731 - mean_absolute_error: 6.3731 - val_loss: 7.0635 - val_mean_absolute_error: 7.0635
# Epoch 72/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.3996 - mean_absolute_error: 6.3996 - val_loss: 7.4737 - val_mean_absolute_error: 7.4737
# Epoch 73/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.3917 - mean_absolute_error: 6.3917 - val_loss: 7.1630 - val_mean_absolute_error: 7.1630
# Epoch 74/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.2987 - mean_absolute_error: 6.2987 - val_loss: 7.4529 - val_mean_absolute_error: 7.4529
# Epoch 75/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.3674 - mean_absolute_error: 6.3674 - val_loss: 8.2322 - val_mean_absolute_error: 8.2322
# Epoch 76/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.3445 - mean_absolute_error: 6.3445 - val_loss: 6.8681 - val_mean_absolute_error: 6.8681
# Epoch 77/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.2285 - mean_absolute_error: 6.2285 - val_loss: 6.7688 - val_mean_absolute_error: 6.7688
# Epoch 78/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.2427 - mean_absolute_error: 6.2427 - val_loss: 8.2440 - val_mean_absolute_error: 8.2440
# Epoch 79/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.2314 - mean_absolute_error: 6.2314 - val_loss: 6.6247 - val_mean_absolute_error: 6.6247
# Epoch 80/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.2589 - mean_absolute_error: 6.2589 - val_loss: 9.8665 - val_mean_absolute_error: 9.8665
# Epoch 81/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.2517 - mean_absolute_error: 6.2517 - val_loss: 9.9101 - val_mean_absolute_error: 9.9101
# Epoch 82/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.2070 - mean_absolute_error: 6.2070 - val_loss: 9.2877 - val_mean_absolute_error: 9.2877
# Epoch 83/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.2685 - mean_absolute_error: 6.2685 - val_loss: 6.5896 - val_mean_absolute_error: 6.5896
# Epoch 84/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.2206 - mean_absolute_error: 6.2206 - val_loss: 6.6019 - val_mean_absolute_error: 6.60196.2179 - mean_absolut - ETA: 0s - loss: 6.2122 - mean_absolute_error: 6.21
# Epoch 85/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.2521 - mean_absolute_error: 6.2521 - val_loss: 7.6486 - val_mean_absolute_error: 7.6486
# Epoch 86/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.1727 - mean_absolute_error: 6.1727 - val_loss: 8.0114 - val_mean_absolute_error: 8.0114
# Epoch 87/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.1474 - mean_absolute_error: 6.1474 - val_loss: 6.5300 - val_mean_absolute_error: 6.5300
# Epoch 88/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.1640 - mean_absolute_error: 6.1640 - val_loss: 6.6106 - val_mean_absolute_error: 6.6106
# Epoch 89/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.1264 - mean_absolute_error: 6.1264 - val_loss: 10.8256 - val_mean_absolute_error: 10.8256
# Epoch 90/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.1583 - mean_absolute_error: 6.1583 - val_loss: 6.9035 - val_mean_absolute_error: 6.9035
# Epoch 91/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.1367 - mean_absolute_error: 6.1367 - val_loss: 6.6636 - val_mean_absolute_error: 6.6636 ETA: 2s - loss: 6.1648 -  - ETA: 0s - loss: 6.1700 - mean_abs
# Epoch 92/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.1840 - mean_absolute_error: 6.1840 - val_loss: 6.8806 - val_mean_absolute_error: 6.8806
# Epoch 93/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.1770 - mean_absolute_error: 6.1770 - val_loss: 6.7373 - val_mean_absolute_error: 6.7373
# Epoch 94/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.0442 - mean_absolute_error: 6.0442 - val_loss: 10.6854 - val_mean_absolute_error: 10.6854 - ETA: 0s - loss: 6.0372 - mean_absolute_error: 6.
# Epoch 95/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.1278 - mean_absolute_error: 6.1278 - val_loss: 7.0317 - val_mean_absolute_error: 7.0317
# Epoch 96/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.1807 - mean_absolute_error: 6.1807 - val_loss: 7.0334 - val_mean_absolute_error: 7.0334
# Epoch 97/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.0508 - mean_absolute_error: 6.0508 - val_loss: 7.4030 - val_mean_absolute_error: 7.4030
# Epoch 98/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.0963 - mean_absolute_error: 6.0963 - val_loss: 9.8659 - val_mean_absolute_error: 9.8659
# Epoch 99/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.1015 - mean_absolute_error: 6.1015 - val_loss: 6.9073 - val_mean_absolute_error: 6.9073
# Epoch 100/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.0788 - mean_absolute_error: 6.0788 - val_loss: 7.7298 - val_mean_absolute_error: 7.7298
# Epoch 101/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.0788 - mean_absolute_error: 6.0788 - val_loss: 6.6174 - val_mean_absolute_error: 6.6174
# Epoch 102/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.0782 - mean_absolute_error: 6.0782 - val_loss: 9.5530 - val_mean_absolute_error: 9.5530
# Epoch 103/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.0467 - mean_absolute_error: 6.0467 - val_loss: 7.3402 - val_mean_absolute_error: 7.3402
# Epoch 104/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.0668 - mean_absolute_error: 6.0668 - val_loss: 7.0971 - val_mean_absolute_error: 7.0971
# Epoch 105/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.0608 - mean_absolute_error: 6.0608 - val_loss: 6.6431 - val_mean_absolute_error: 6.6431
# Epoch 106/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.0384 - mean_absolute_error: 6.0384 - val_loss: 6.5914 - val_mean_absolute_error: 6.5914
# Epoch 107/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.0175 - mean_absolute_error: 6.0175 - val_loss: 9.6275 - val_mean_absolute_error: 9.6275
# Epoch 108/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.0582 - mean_absolute_error: 6.0582 - val_loss: 6.9656 - val_mean_absolute_error: 6.9656
# Epoch 109/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9984 - mean_absolute_error: 5.9984 - val_loss: 6.6172 - val_mean_absolute_error: 6.6172
# Epoch 110/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.0403 - mean_absolute_error: 6.0403 - val_loss: 7.1622 - val_mean_absolute_error: 7.1622
# Epoch 111/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9697 - mean_absolute_error: 5.9697 - val_loss: 7.2388 - val_mean_absolute_error: 7.2388
# Epoch 112/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 6.0364 - mean_absolute_error: 6.0364 - val_loss: 7.8139 - val_mean_absolute_error: 7.8139
# Epoch 113/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9816 - mean_absolute_error: 5.9816 - val_loss: 6.6240 - val_mean_absolute_error: 6.6240
# Epoch 114/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9622 - mean_absolute_error: 5.9622 - val_loss: 8.2589 - val_mean_absolute_error: 8.2589
# Epoch 115/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 6.0359 - mean_absolute_error: 6.0359 - val_loss: 7.9414 - val_mean_absolute_error: 7.9414
# Epoch 116/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.9034 - mean_absolute_error: 5.9034 - val_loss: 6.9052 - val_mean_absolute_error: 6.9052
# Epoch 117/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9915 - mean_absolute_error: 5.9915 - val_loss: 6.8205 - val_mean_absolute_error: 6.8205
# Epoch 118/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.9542 - mean_absolute_error: 5.9542 - val_loss: 6.5193 - val_mean_absolute_error: 6.5193
# Epoch 119/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9747 - mean_absolute_error: 5.9747 - val_loss: 8.2136 - val_mean_absolute_error: 8.2136
# Epoch 120/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9710 - mean_absolute_error: 5.9710 - val_loss: 6.9692 - val_mean_absolute_error: 6.9692
# Epoch 121/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9575 - mean_absolute_error: 5.9575 - val_loss: 8.0470 - val_mean_absolute_error: 8.0470
# Epoch 122/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9099 - mean_absolute_error: 5.9099 - val_loss: 6.6377 - val_mean_absolute_error: 6.6377
# Epoch 123/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9332 - mean_absolute_error: 5.9332 - val_loss: 8.9130 - val_mean_absolute_error: 8.9130
# Epoch 124/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9455 - mean_absolute_error: 5.9455 - val_loss: 6.6762 - val_mean_absolute_error: 6.6762
# Epoch 125/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8387 - mean_absolute_error: 5.8387 - val_loss: 6.4687 - val_mean_absolute_error: 6.4687
# Epoch 126/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9298 - mean_absolute_error: 5.9298 - val_loss: 6.5201 - val_mean_absolute_error: 6.5201
# Epoch 127/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9297 - mean_absolute_error: 5.9297 - val_loss: 6.5625 - val_mean_absolute_error: 6.5625
# Epoch 128/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9256 - mean_absolute_error: 5.9256 - val_loss: 6.7332 - val_mean_absolute_error: 6.7332
# Epoch 129/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.9628 - mean_absolute_error: 5.9628 - val_loss: 12.2327 - val_mean_absolute_error: 12.2327TA: 2s - los - ETA: 0s - loss: 5.9497 - mean_absolute_
# Epoch 130/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8872 - mean_absolute_error: 5.8872 - val_loss: 11.0342 - val_mean_absolute_error: 11.0342
# Epoch 131/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9579 - mean_absolute_error: 5.9579 - val_loss: 6.4797 - val_mean_absolute_error: 6.4797
# Epoch 132/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8536 - mean_absolute_error: 5.8536 - val_loss: 6.6831 - val_mean_absolute_error: 6.6831
# Epoch 133/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8425 - mean_absolute_error: 5.8425 - val_loss: 8.4651 - val_mean_absolute_error: 8.4651  - ETA: 0s - loss: 5.8339 - mean_absolute_erro
# Epoch 134/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.9102 - mean_absolute_error: 5.9102 - val_loss: 6.4776 - val_mean_absolute_error: 6.4776
# Epoch 135/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8306 - mean_absolute_error: 5.8306 - val_loss: 7.7419 - val_mean_absolute_error: 7.7419
# Epoch 136/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8488 - mean_absolute_error: 5.8488 - val_loss: 7.0276 - val_mean_absolute_error: 7.0276
# Epoch 137/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8473 - mean_absolute_error: 5.8473 - val_loss: 8.1839 - val_mean_absolute_error: 8.1839
# Epoch 138/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8978 - mean_absolute_error: 5.8978 - val_loss: 6.5202 - val_mean_absolute_error: 6.5202
# Epoch 139/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8747 - mean_absolute_error: 5.8747 - val_loss: 6.5096 - val_mean_absolute_error: 6.5096
# Epoch 140/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7771 - mean_absolute_error: 5.7771 - val_loss: 6.9837 - val_mean_absolute_error: 6.9837
# Epoch 141/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8204 - mean_absolute_error: 5.8204 - val_loss: 10.7181 - val_mean_absolute_error: 10.7181
# Epoch 142/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8558 - mean_absolute_error: 5.8558 - val_loss: 7.9563 - val_mean_absolute_error: 7.9563
# Epoch 143/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7884 - mean_absolute_error: 5.7884 - val_loss: 6.9562 - val_mean_absolute_error: 6.9562
# Epoch 144/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7840 - mean_absolute_error: 5.7840 - val_loss: 7.0439 - val_mean_absolute_error: 7.0439solute_error: 5.783
# Epoch 145/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7331 - mean_absolute_error: 5.7331 - val_loss: 7.1177 - val_mean_absolute_error: 7.1177
# Epoch 146/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7824 - mean_absolute_error: 5.7824 - val_loss: 6.8963 - val_mean_absolute_error: 6.8963
# Epoch 147/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7751 - mean_absolute_error: 5.7751 - val_loss: 6.8579 - val_mean_absolute_error: 6.8579
# Epoch 148/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8047 - mean_absolute_error: 5.8047 - val_loss: 6.6164 - val_mean_absolute_error: 6.6164
# Epoch 149/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8235 - mean_absolute_error: 5.8235 - val_loss: 6.6007 - val_mean_absolute_error: 6.6007
# Epoch 150/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7552 - mean_absolute_error: 5.7552 - val_loss: 6.9927 - val_mean_absolute_error: 6.9927
# Epoch 151/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8582 - mean_absolute_error: 5.8582 - val_loss: 6.4953 - val_mean_absolute_error: 6.4953
# Epoch 152/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.7793 - mean_absolute_error: 5.7793 - val_loss: 6.7294 - val_mean_absolute_error: 6.7294
# Epoch 153/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.7826 - mean_absolute_error: 5.7826 - val_loss: 6.9064 - val_mean_absolute_error: 6.9064
# Epoch 154/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.8077 - mean_absolute_error: 5.8077 - val_loss: 6.5312 - val_mean_absolute_error: 6.5312
# Epoch 155/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.8091 - mean_absolute_error: 5.8091 - val_loss: 7.9995 - val_mean_absolute_error: 7.9995
# Epoch 156/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.7751 - mean_absolute_error: 5.7751 - val_loss: 6.7456 - val_mean_absolute_error: 6.7456
# Epoch 157/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.7959 - mean_absolute_error: 5.7959 - val_loss: 7.1523 - val_mean_absolute_error: 7.1523
# Epoch 158/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.6961 - mean_absolute_error: 5.6961 - val_loss: 8.2655 - val_mean_absolute_error: 8.2655
# Epoch 159/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.7665 - mean_absolute_error: 5.7665 - val_loss: 6.4779 - val_mean_absolute_error: 6.4779
# Epoch 160/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.7371 - mean_absolute_error: 5.7371 - val_loss: 6.5323 - val_mean_absolute_error: 6.5323
# Epoch 161/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.7565 - mean_absolute_error: 5.7565 - val_loss: 6.6672 - val_mean_absolute_error: 6.6672
# Epoch 162/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.7028 - mean_absolute_error: 5.7028 - val_loss: 8.4095 - val_mean_absolute_error: 8.4095
# Epoch 163/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.7891 - mean_absolute_error: 5.7891 - val_loss: 7.3154 - val_mean_absolute_error: 7.3154
# Epoch 164/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7064 - mean_absolute_error: 5.7064 - val_loss: 6.4951 - val_mean_absolute_error: 6.4951
# Epoch 165/400
# 1280/1280 [==============================] - 8s 6ms/step - loss: 5.7391 - mean_absolute_error: 5.7391 - val_loss: 6.4065 - val_mean_absolute_error: 6.4065
# Epoch 166/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6475 - mean_absolute_error: 5.6475 - val_loss: 6.3818 - val_mean_absolute_error: 6.3818
# Epoch 167/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5985 - mean_absolute_error: 5.5985 - val_loss: 6.4977 - val_mean_absolute_error: 6.4977
# Epoch 168/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7566 - mean_absolute_error: 5.7566 - val_loss: 10.7118 - val_mean_absolute_error: 10.7118
# Epoch 169/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7440 - mean_absolute_error: 5.7440 - val_loss: 6.3748 - val_mean_absolute_error: 6.3748
# Epoch 170/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6423 - mean_absolute_error: 5.6423 - val_loss: 6.4254 - val_mean_absolute_error: 6.4254
# Epoch 171/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7671 - mean_absolute_error: 5.7671 - val_loss: 6.3383 - val_mean_absolute_error: 6.3383
# Epoch 172/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6970 - mean_absolute_error: 5.6970 - val_loss: 7.0155 - val_mean_absolute_error: 7.0155
# Epoch 173/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7885 - mean_absolute_error: 5.7885 - val_loss: 10.4295 - val_mean_absolute_error: 10.4295
# Epoch 174/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7248 - mean_absolute_error: 5.7248 - val_loss: 6.3338 - val_mean_absolute_error: 6.3338
# Epoch 175/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6655 - mean_absolute_error: 5.6655 - val_loss: 6.4444 - val_mean_absolute_error: 6.4444
# Epoch 176/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6382 - mean_absolute_error: 5.6382 - val_loss: 6.9511 - val_mean_absolute_error: 6.9511
# Epoch 177/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6440 - mean_absolute_error: 5.6440 - val_loss: 9.3572 - val_mean_absolute_error: 9.3572
# Epoch 178/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6178 - mean_absolute_error: 5.6178 - val_loss: 9.7866 - val_mean_absolute_error: 9.7866
# Epoch 179/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7572 - mean_absolute_error: 5.7572 - val_loss: 6.4096 - val_mean_absolute_error: 6.4096
# Epoch 180/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6991 - mean_absolute_error: 5.6991 - val_loss: 6.5528 - val_mean_absolute_error: 6.5528
# Epoch 181/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6669 - mean_absolute_error: 5.6669 - val_loss: 6.5537 - val_mean_absolute_error: 6.5537
# Epoch 182/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6558 - mean_absolute_error: 5.6558 - val_loss: 6.7562 - val_mean_absolute_error: 6.7562
# Epoch 183/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6966 - mean_absolute_error: 5.6966 - val_loss: 6.7823 - val_mean_absolute_error: 6.7823
# Epoch 184/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5890 - mean_absolute_error: 5.5890 - val_loss: 6.4772 - val_mean_absolute_error: 6.4772
# Epoch 185/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7051 - mean_absolute_error: 5.7051 - val_loss: 7.0362 - val_mean_absolute_error: 7.0362
# Epoch 186/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6463 - mean_absolute_error: 5.6463 - val_loss: 6.3530 - val_mean_absolute_error: 6.3530
# Epoch 187/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7295 - mean_absolute_error: 5.7295 - val_loss: 6.4837 - val_mean_absolute_error: 6.4837
# Epoch 188/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6517 - mean_absolute_error: 5.6517 - val_loss: 8.5581 - val_mean_absolute_error: 8.5581
# Epoch 189/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6491 - mean_absolute_error: 5.6491 - val_loss: 6.9061 - val_mean_absolute_error: 6.9061
# Epoch 190/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6900 - mean_absolute_error: 5.6900 - val_loss: 6.3902 - val_mean_absolute_error: 6.3902
# Epoch 191/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.7301 - mean_absolute_error: 5.7301 - val_loss: 6.7025 - val_mean_absolute_error: 6.7025
# Epoch 192/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6205 - mean_absolute_error: 5.6205 - val_loss: 8.9331 - val_mean_absolute_error: 8.9331
# Epoch 193/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6282 - mean_absolute_error: 5.6282 - val_loss: 7.0536 - val_mean_absolute_error: 7.0536
# Epoch 194/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6241 - mean_absolute_error: 5.6241 - val_loss: 6.6347 - val_mean_absolute_error: 6.6347
# Epoch 195/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6442 - mean_absolute_error: 5.6442 - val_loss: 6.3980 - val_mean_absolute_error: 6.3980oss: 5.6288 - mean_abs
# Epoch 196/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7009 - mean_absolute_error: 5.7009 - val_loss: 7.4529 - val_mean_absolute_error: 7.4529
# Epoch 197/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5944 - mean_absolute_error: 5.5944 - val_loss: 6.6233 - val_mean_absolute_error: 6.6233
# Epoch 198/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6016 - mean_absolute_error: 5.6016 - val_loss: 8.0281 - val_mean_absolute_error: 8.0281
# Epoch 199/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6009 - mean_absolute_error: 5.6009 - val_loss: 9.5814 - val_mean_absolute_error: 9.5814
# Epoch 200/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6280 - mean_absolute_error: 5.6280 - val_loss: 6.3708 - val_mean_absolute_error: 6.3708
# Epoch 201/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5728 - mean_absolute_error: 5.5728 - val_loss: 7.0166 - val_mean_absolute_error: 7.0166
# Epoch 202/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.7101 - mean_absolute_error: 5.7101 - val_loss: 6.4204 - val_mean_absolute_error: 6.4204
# Epoch 203/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6310 - mean_absolute_error: 5.6310 - val_loss: 7.5509 - val_mean_absolute_error: 7.5509
# Epoch 204/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6488 - mean_absolute_error: 5.6488 - val_loss: 6.4889 - val_mean_absolute_error: 6.4889
# Epoch 205/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6365 - mean_absolute_error: 5.6365 - val_loss: 6.7435 - val_mean_absolute_error: 6.7435
# Epoch 206/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6122 - mean_absolute_error: 5.6122 - val_loss: 8.4730 - val_mean_absolute_error: 8.4730
# Epoch 207/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5685 - mean_absolute_error: 5.5685 - val_loss: 7.3857 - val_mean_absolute_error: 7.3857
# Epoch 208/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5986 - mean_absolute_error: 5.5986 - val_loss: 6.6039 - val_mean_absolute_error: 6.6039
# Epoch 209/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6259 - mean_absolute_error: 5.6259 - val_loss: 6.4171 - val_mean_absolute_error: 6.4171
# Epoch 210/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6488 - mean_absolute_error: 5.6488 - val_loss: 7.3730 - val_mean_absolute_error: 7.3730
# Epoch 211/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5999 - mean_absolute_error: 5.5999 - val_loss: 7.0408 - val_mean_absolute_error: 7.0408
# Epoch 212/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6248 - mean_absolute_error: 5.6248 - val_loss: 6.5841 - val_mean_absolute_error: 6.5841
# Epoch 213/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6245 - mean_absolute_error: 5.6245 - val_loss: 8.3221 - val_mean_absolute_error: 8.3221
# Epoch 214/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6245 - mean_absolute_error: 5.6245 - val_loss: 7.6164 - val_mean_absolute_error: 7.6164
# Epoch 215/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5560 - mean_absolute_error: 5.5560 - val_loss: 6.5109 - val_mean_absolute_error: 6.5109
# Epoch 216/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6209 - mean_absolute_error: 5.6209 - val_loss: 9.2358 - val_mean_absolute_error: 9.2358
# Epoch 217/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5672 - mean_absolute_error: 5.5672 - val_loss: 6.5094 - val_mean_absolute_error: 6.5094
# Epoch 218/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5904 - mean_absolute_error: 5.5904 - val_loss: 6.3051 - val_mean_absolute_error: 6.3051
# Epoch 219/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5962 - mean_absolute_error: 5.5962 - val_loss: 6.4469 - val_mean_absolute_error: 6.4469
# Epoch 220/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5661 - mean_absolute_error: 5.5661 - val_loss: 6.3004 - val_mean_absolute_error: 6.3004
# Epoch 221/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5580 - mean_absolute_error: 5.5580 - val_loss: 6.3118 - val_mean_absolute_error: 6.3118
# Epoch 222/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5592 - mean_absolute_error: 5.5592 - val_loss: 6.4177 - val_mean_absolute_error: 6.4177
# Epoch 223/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6271 - mean_absolute_error: 5.6271 - val_loss: 7.8710 - val_mean_absolute_error: 7.8710
# Epoch 224/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5776 - mean_absolute_error: 5.5776 - val_loss: 6.3364 - val_mean_absolute_error: 6.3364
# Epoch 225/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6199 - mean_absolute_error: 5.6199 - val_loss: 6.8986 - val_mean_absolute_error: 6.8986
# Epoch 226/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5395 - mean_absolute_error: 5.5395 - val_loss: 6.3325 - val_mean_absolute_error: 6.3325
# Epoch 227/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4855 - mean_absolute_error: 5.4855 - val_loss: 7.0632 - val_mean_absolute_error: 7.0632
# Epoch 228/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5874 - mean_absolute_error: 5.5874 - val_loss: 6.6753 - val_mean_absolute_error: 6.6753
# Epoch 229/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5088 - mean_absolute_error: 5.5088 - val_loss: 9.1403 - val_mean_absolute_error: 9.1403
# Epoch 230/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5891 - mean_absolute_error: 5.5891 - val_loss: 6.5715 - val_mean_absolute_error: 6.5715
# Epoch 231/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6006 - mean_absolute_error: 5.6006 - val_loss: 6.2998 - val_mean_absolute_error: 6.2998
# Epoch 232/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5166 - mean_absolute_error: 5.5166 - val_loss: 6.9349 - val_mean_absolute_error: 6.9349
# Epoch 233/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5578 - mean_absolute_error: 5.5578 - val_loss: 7.9609 - val_mean_absolute_error: 7.9609
# Epoch 234/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5094 - mean_absolute_error: 5.5094 - val_loss: 6.3165 - val_mean_absolute_error: 6.3165
# Epoch 235/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5952 - mean_absolute_error: 5.5952 - val_loss: 6.6383 - val_mean_absolute_error: 6.6383
# Epoch 236/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4870 - mean_absolute_error: 5.4870 - val_loss: 6.3833 - val_mean_absolute_error: 6.3833
# Epoch 237/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6055 - mean_absolute_error: 5.6055 - val_loss: 7.1027 - val_mean_absolute_error: 7.1027
# Epoch 238/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5942 - mean_absolute_error: 5.5942 - val_loss: 6.9573 - val_mean_absolute_error: 6.9573
# Epoch 239/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5728 - mean_absolute_error: 5.5728 - val_loss: 7.6072 - val_mean_absolute_error: 7.6072
# Epoch 240/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.5139 - mean_absolute_error: 5.5139 - val_loss: 6.3680 - val_mean_absolute_error: 6.3680
# Epoch 241/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5764 - mean_absolute_error: 5.5764 - val_loss: 6.4159 - val_mean_absolute_error: 6.4159
# Epoch 242/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5151 - mean_absolute_error: 5.5151 - val_loss: 6.5652 - val_mean_absolute_error: 6.5652
# Epoch 243/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5193 - mean_absolute_error: 5.5193 - val_loss: 6.6933 - val_mean_absolute_error: 6.6933
# Epoch 244/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.6642 - mean_absolute_error: 5.6642 - val_loss: 6.3962 - val_mean_absolute_error: 6.3962
# Epoch 245/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.4521 - mean_absolute_error: 5.4521 - val_loss: 7.3048 - val_mean_absolute_error: 7.3048
# Epoch 246/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5634 - mean_absolute_error: 5.5634 - val_loss: 6.9798 - val_mean_absolute_error: 6.9798
# Epoch 247/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.4743 - mean_absolute_error: 5.4743 - val_loss: 6.6443 - val_mean_absolute_error: 6.6443
# Epoch 248/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4943 - mean_absolute_error: 5.4943 - val_loss: 6.5335 - val_mean_absolute_error: 6.5335
# Epoch 249/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5585 - mean_absolute_error: 5.5585 - val_loss: 6.5207 - val_mean_absolute_error: 6.5207
# Epoch 250/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5277 - mean_absolute_error: 5.5277 - val_loss: 6.4737 - val_mean_absolute_error: 6.4737
# Epoch 251/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5346 - mean_absolute_error: 5.5346 - val_loss: 7.2484 - val_mean_absolute_error: 7.2484
# Epoch 252/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5044 - mean_absolute_error: 5.5044 - val_loss: 13.0751 - val_mean_absolute_error: 13.0751
# Epoch 253/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4351 - mean_absolute_error: 5.4351 - val_loss: 6.7469 - val_mean_absolute_error: 6.7469
# Epoch 254/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5386 - mean_absolute_error: 5.5386 - val_loss: 6.8027 - val_mean_absolute_error: 6.8027
# Epoch 255/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4669 - mean_absolute_error: 5.4669 - val_loss: 6.5135 - val_mean_absolute_error: 6.5135
# Epoch 256/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5041 - mean_absolute_error: 5.5041 - val_loss: 6.3683 - val_mean_absolute_error: 6.3683
# Epoch 257/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4939 - mean_absolute_error: 5.4939 - val_loss: 6.5068 - val_mean_absolute_error: 6.5068
# Epoch 258/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4757 - mean_absolute_error: 5.4757 - val_loss: 6.6620 - val_mean_absolute_error: 6.6620
# Epoch 259/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5214 - mean_absolute_error: 5.5214 - val_loss: 7.6619 - val_mean_absolute_error: 7.6619
# Epoch 260/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5925 - mean_absolute_error: 5.5925 - val_loss: 9.9444 - val_mean_absolute_error: 9.9444
# Epoch 261/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5163 - mean_absolute_error: 5.5163 - val_loss: 8.0166 - val_mean_absolute_error: 8.0166
# Epoch 262/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5564 - mean_absolute_error: 5.5564 - val_loss: 8.7079 - val_mean_absolute_error: 8.7079
# Epoch 263/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5115 - mean_absolute_error: 5.5115 - val_loss: 7.7385 - val_mean_absolute_error: 7.7385
# Epoch 264/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4636 - mean_absolute_error: 5.4636 - val_loss: 6.4421 - val_mean_absolute_error: 6.4421
# Epoch 265/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4750 - mean_absolute_error: 5.4750 - val_loss: 6.8475 - val_mean_absolute_error: 6.8475
# Epoch 266/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5590 - mean_absolute_error: 5.5590 - val_loss: 7.9840 - val_mean_absolute_error: 7.9840
# Epoch 267/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4679 - mean_absolute_error: 5.4679 - val_loss: 6.4643 - val_mean_absolute_error: 6.4643
# Epoch 268/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5340 - mean_absolute_error: 5.5340 - val_loss: 7.1902 - val_mean_absolute_error: 7.1902
# Epoch 269/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4716 - mean_absolute_error: 5.4716 - val_loss: 6.6691 - val_mean_absolute_error: 6.6691
# Epoch 270/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4843 - mean_absolute_error: 5.4843 - val_loss: 7.1598 - val_mean_absolute_error: 7.1598
# Epoch 271/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4513 - mean_absolute_error: 5.4513 - val_loss: 6.4809 - val_mean_absolute_error: 6.4809
# Epoch 272/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5421 - mean_absolute_error: 5.5421 - val_loss: 6.3943 - val_mean_absolute_error: 6.3943
# Epoch 273/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5178 - mean_absolute_error: 5.5178 - val_loss: 6.9317 - val_mean_absolute_error: 6.9317
# Epoch 274/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4632 - mean_absolute_error: 5.4632 - val_loss: 8.2214 - val_mean_absolute_error: 8.2214
# Epoch 275/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5424 - mean_absolute_error: 5.5424 - val_loss: 7.2823 - val_mean_absolute_error: 7.2823
# Epoch 276/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4487 - mean_absolute_error: 5.4487 - val_loss: 8.3980 - val_mean_absolute_error: 8.3980
# Epoch 277/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4524 - mean_absolute_error: 5.4524 - val_loss: 10.6897 - val_mean_absolute_error: 10.6897
# Epoch 278/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4681 - mean_absolute_error: 5.4681 - val_loss: 8.0321 - val_mean_absolute_error: 8.0321
# Epoch 279/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4325 - mean_absolute_error: 5.4325 - val_loss: 6.4645 - val_mean_absolute_error: 6.4645
# Epoch 280/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5325 - mean_absolute_error: 5.5325 - val_loss: 6.6398 - val_mean_absolute_error: 6.6398
# Epoch 281/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4554 - mean_absolute_error: 5.4554 - val_loss: 7.0825 - val_mean_absolute_error: 7.0825
# Epoch 282/400
# ...
# Epoch 302/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4436 - mean_absolute_error: 5.4436 - val_loss: 8.7372 - val_mean_absolute_error: 8.7372
# Epoch 303/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4071 - mean_absolute_error: 5.4071 - val_loss: 6.2792 - val_mean_absolute_error: 6.2792
# Epoch 304/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.5207 - mean_absolute_error: 5.5207 - val_loss: 7.9505 - val_mean_absolute_error: 7.9505
# Epoch 305/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4174 - mean_absolute_error: 5.4174 - val_loss: 6.3990 - val_mean_absolute_error: 6.3990
# Epoch 306/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4178 - mean_absolute_error: 5.4178 - val_loss: 6.5680 - val_mean_absolute_error: 6.5680
# Epoch 307/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4524 - mean_absolute_error: 5.4524 - val_loss: 6.3654 - val_mean_absolute_error: 6.3654
# Epoch 308/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4720 - mean_absolute_error: 5.4720 - val_loss: 7.6068 - val_mean_absolute_error: 7.6068
# Epoch 309/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4289 - mean_absolute_error: 5.4289 - val_loss: 7.2607 - val_mean_absolute_error: 7.2607
# Epoch 310/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4812 - mean_absolute_error: 5.4812 - val_loss: 6.4729 - val_mean_absolute_error: 6.4729
# Epoch 311/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4416 - mean_absolute_error: 5.4416 - val_loss: 6.2987 - val_mean_absolute_error: 6.2987
# Epoch 312/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4037 - mean_absolute_error: 5.4037 - val_loss: 6.4020 - val_mean_absolute_error: 6.4020
# Epoch 313/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4411 - mean_absolute_error: 5.4411 - val_loss: 6.8846 - val_mean_absolute_error: 6.8846
# Epoch 314/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4812 - mean_absolute_error: 5.4812 - val_loss: 6.3778 - val_mean_absolute_error: 6.3778
# Epoch 315/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4526 - mean_absolute_error: 5.4526 - val_loss: 6.3552 - val_mean_absolute_error: 6.3552
# Epoch 316/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4159 - mean_absolute_error: 5.4159 - val_loss: 6.5677 - val_mean_absolute_error: 6.5677
# Epoch 317/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4876 - mean_absolute_error: 5.4876 - val_loss: 6.5366 - val_mean_absolute_error: 6.5366
# Epoch 318/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4360 - mean_absolute_error: 5.4360 - val_loss: 6.4889 - val_mean_absolute_error: 6.4889
# Epoch 319/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4092 - mean_absolute_error: 5.4092 - val_loss: 6.4862 - val_mean_absolute_error: 6.4862
# Epoch 320/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4777 - mean_absolute_error: 5.4777 - val_loss: 6.2703 - val_mean_absolute_error: 6.2703
# Epoch 321/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4889 - mean_absolute_error: 5.4889 - val_loss: 7.0063 - val_mean_absolute_error: 7.0063
# Epoch 322/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4366 - mean_absolute_error: 5.4366 - val_loss: 6.2976 - val_mean_absolute_error: 6.2976
# Epoch 323/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3490 - mean_absolute_error: 5.3490 - val_loss: 7.0138 - val_mean_absolute_error: 7.0138
# Epoch 324/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3998 - mean_absolute_error: 5.3998 - val_loss: 6.5584 - val_mean_absolute_error: 6.5584
# Epoch 325/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4578 - mean_absolute_error: 5.4578 - val_loss: 6.5986 - val_mean_absolute_error: 6.5986
# Epoch 326/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3862 - mean_absolute_error: 5.3862 - val_loss: 6.5326 - val_mean_absolute_error: 6.5326
# Epoch 327/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3780 - mean_absolute_error: 5.3780 - val_loss: 6.5684 - val_mean_absolute_error: 6.5684
# Epoch 328/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4248 - mean_absolute_error: 5.4248 - val_loss: 8.5745 - val_mean_absolute_error: 8.5745
# Epoch 329/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4201 - mean_absolute_error: 5.4201 - val_loss: 6.7977 - val_mean_absolute_error: 6.7977
# Epoch 330/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3820 - mean_absolute_error: 5.3820 - val_loss: 6.3985 - val_mean_absolute_error: 6.3985
# Epoch 331/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3910 - mean_absolute_error: 5.3910 - val_loss: 6.5234 - val_mean_absolute_error: 6.5234
# Epoch 332/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4178 - mean_absolute_error: 5.4178 - val_loss: 6.2260 - val_mean_absolute_error: 6.2260
# Epoch 333/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4570 - mean_absolute_error: 5.4570 - val_loss: 6.7335 - val_mean_absolute_error: 6.7335
# Epoch 334/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4226 - mean_absolute_error: 5.4226 - val_loss: 6.3363 - val_mean_absolute_error: 6.3363
# Epoch 335/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4474 - mean_absolute_error: 5.4474 - val_loss: 6.3992 - val_mean_absolute_error: 6.3992
# Epoch 336/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4229 - mean_absolute_error: 5.4229 - val_loss: 7.7536 - val_mean_absolute_error: 7.7536
# Epoch 337/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3933 - mean_absolute_error: 5.3933 - val_loss: 6.6985 - val_mean_absolute_error: 6.6985
# Epoch 338/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4350 - mean_absolute_error: 5.4350 - val_loss: 6.8249 - val_mean_absolute_error: 6.8249olute_error:
# Epoch 339/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3947 - mean_absolute_error: 5.3947 - val_loss: 6.4654 - val_mean_absolute_error: 6.4654mean_absolute
# Epoch 340/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4144 - mean_absolute_error: 5.4144 - val_loss: 6.4160 - val_mean_absolute_error: 6.4160
# Epoch 341/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4571 - mean_absolute_error: 5.4571 - val_loss: 6.5994 - val_mean_absolute_error: 6.5994
# Epoch 342/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4261 - mean_absolute_error: 5.4261 - val_loss: 7.1690 - val_mean_absolute_error: 7.1690
# Epoch 343/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3874 - mean_absolute_error: 5.3874 - val_loss: 6.5684 - val_mean_absolute_error: 6.5684
# Epoch 344/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4468 - mean_absolute_error: 5.4468 - val_loss: 6.7820 - val_mean_absolute_error: 6.7820
# Epoch 345/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3751 - mean_absolute_error: 5.3751 - val_loss: 8.0583 - val_mean_absolute_error: 8.0583
# Epoch 346/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3912 - mean_absolute_error: 5.3912 - val_loss: 6.2876 - val_mean_absolute_error: 6.2876
# Epoch 347/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3948 - mean_absolute_error: 5.3948 - val_loss: 6.4163 - val_mean_absolute_error: 6.4163
# Epoch 348/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3689 - mean_absolute_error: 5.3689 - val_loss: 6.9800 - val_mean_absolute_error: 6.9800
# Epoch 349/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4518 - mean_absolute_error: 5.4518 - val_loss: 6.3770 - val_mean_absolute_error: 6.3770
# Epoch 350/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4322 - mean_absolute_error: 5.4322 - val_loss: 6.4340 - val_mean_absolute_error: 6.4340
# Epoch 351/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4444 - mean_absolute_error: 5.4444 - val_loss: 6.6782 - val_mean_absolute_error: 6.6782
# Epoch 352/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4108 - mean_absolute_error: 5.4108 - val_loss: 7.0546 - val_mean_absolute_error: 7.0546
# Epoch 353/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3750 - mean_absolute_error: 5.3750 - val_loss: 6.4118 - val_mean_absolute_error: 6.4118
# Epoch 354/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3779 - mean_absolute_error: 5.3779 - val_loss: 6.3026 - val_mean_absolute_error: 6.3026
# Epoch 355/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3702 - mean_absolute_error: 5.3702 - val_loss: 6.2772 - val_mean_absolute_error: 6.2772
# Epoch 356/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4222 - mean_absolute_error: 5.4222 - val_loss: 6.3075 - val_mean_absolute_error: 6.3075
# Epoch 357/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4285 - mean_absolute_error: 5.4285 - val_loss: 6.4876 - val_mean_absolute_error: 6.4876
# Epoch 358/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3670 - mean_absolute_error: 5.3670 - val_loss: 6.5742 - val_mean_absolute_error: 6.5742
# Epoch 359/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.2977 - mean_absolute_error: 5.2977 - val_loss: 8.8668 - val_mean_absolute_error: 8.8668
# Epoch 360/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3796 - mean_absolute_error: 5.3796 - val_loss: 6.4090 - val_mean_absolute_error: 6.4090
# Epoch 361/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4197 - mean_absolute_error: 5.4197 - val_loss: 6.8991 - val_mean_absolute_error: 6.8991
# Epoch 362/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3965 - mean_absolute_error: 5.3965 - val_loss: 8.1470 - val_mean_absolute_error: 8.1470
# Epoch 363/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4322 - mean_absolute_error: 5.4322 - val_loss: 6.3003 - val_mean_absolute_error: 6.3003
# Epoch 364/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4097 - mean_absolute_error: 5.4097 - val_loss: 7.9229 - val_mean_absolute_error: 7.9229
# Epoch 365/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3395 - mean_absolute_error: 5.3395 - val_loss: 6.2715 - val_mean_absolute_error: 6.2715
# Epoch 366/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4191 - mean_absolute_error: 5.4191 - val_loss: 6.6435 - val_mean_absolute_error: 6.6435
# Epoch 367/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3376 - mean_absolute_error: 5.3376 - val_loss: 6.9508 - val_mean_absolute_error: 6.9508
# Epoch 368/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4089 - mean_absolute_error: 5.4089 - val_loss: 6.6030 - val_mean_absolute_error: 6.6030
# Epoch 369/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4040 - mean_absolute_error: 5.4040 - val_loss: 7.0282 - val_mean_absolute_error: 7.0282
# Epoch 370/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.4058 - mean_absolute_error: 5.4058 - val_loss: 6.5392 - val_mean_absolute_error: 6.5392
# Epoch 371/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3325 - mean_absolute_error: 5.3325 - val_loss: 6.5054 - val_mean_absolute_error: 6.5054
# Epoch 372/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3205 - mean_absolute_error: 5.3205 - val_loss: 8.1775 - val_mean_absolute_error: 8.1775
# Epoch 373/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3562 - mean_absolute_error: 5.3562 - val_loss: 6.4744 - val_mean_absolute_error: 6.4744
# Epoch 374/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3169 - mean_absolute_error: 5.3169 - val_loss: 6.3877 - val_mean_absolute_error: 6.3877
# Epoch 375/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3801 - mean_absolute_error: 5.3801 - val_loss: 8.5637 - val_mean_absolute_error: 8.5637
# Epoch 376/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3389 - mean_absolute_error: 5.3389 - val_loss: 10.6885 - val_mean_absolute_error: 10.6885
# Epoch 377/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3698 - mean_absolute_error: 5.3698 - val_loss: 7.5579 - val_mean_absolute_error: 7.5579
# Epoch 378/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3599 - mean_absolute_error: 5.3599 - val_loss: 6.3706 - val_mean_absolute_error: 6.3706
# Epoch 379/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3928 - mean_absolute_error: 5.3928 - val_loss: 7.3230 - val_mean_absolute_error: 7.3230
# Epoch 380/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3828 - mean_absolute_error: 5.3828 - val_loss: 6.3432 - val_mean_absolute_error: 6.3432
# Epoch 381/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3639 - mean_absolute_error: 5.3639 - val_loss: 7.3495 - val_mean_absolute_error: 7.3495
# Epoch 382/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3314 - mean_absolute_error: 5.3314 - val_loss: 7.3413 - val_mean_absolute_error: 7.3413
# Epoch 383/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3502 - mean_absolute_error: 5.3502 - val_loss: 6.3454 - val_mean_absolute_error: 6.3454
# Epoch 384/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3349 - mean_absolute_error: 5.3349 - val_loss: 6.6006 - val_mean_absolute_error: 6.6006
# Epoch 385/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3565 - mean_absolute_error: 5.3565 - val_loss: 6.6501 - val_mean_absolute_error: 6.6501
# Epoch 386/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3873 - mean_absolute_error: 5.3873 - val_loss: 6.4834 - val_mean_absolute_error: 6.4834
# Epoch 387/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3362 - mean_absolute_error: 5.3362 - val_loss: 6.3066 - val_mean_absolute_error: 6.3066
# Epoch 388/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3722 - mean_absolute_error: 5.3722 - val_loss: 6.5579 - val_mean_absolute_error: 6.5579
# Epoch 389/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3350 - mean_absolute_error: 5.3350 - val_loss: 7.5402 - val_mean_absolute_error: 7.5402
# Epoch 390/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3988 - mean_absolute_error: 5.3988 - val_loss: 8.1263 - val_mean_absolute_error: 8.1263
# Epoch 391/400
# 1280/1280 [==============================] - 7s 6ms/step - loss: 5.3699 - mean_absolute_error: 5.3699 - val_loss: 6.3167 - val_mean_absolute_error: 6.3167
# Epoch 392/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.3729 - mean_absolute_error: 5.3729 - val_loss: 7.8379 - val_mean_absolute_error: 7.8379
# Epoch 393/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.3289 - mean_absolute_error: 5.3289 - val_loss: 6.3846 - val_mean_absolute_error: 6.3846
# Epoch 394/400
# 1280/1280 [==============================] - 7s 5ms/step - loss: 5.2912 - mean_absolute_error: 5.2912 - val_loss: 7.0197 - val_mean_absolute_error: 7.0197
# Epoch 395/400
#  640/1280 [==============>...............] - ETA: 3s - loss: 5.3734 - mean_absolute_error: 5.3734

# %%
plt.rcParams["figure.figsize"] = (15,15)
loss = history.history["loss"]
val_loss = history.history["val_loss"]
plt.plot(loss, label = 'loss')
plt.plot(val_loss, label = 'val_loss')
#print('minimum loss:', min(history.history['val_loss']))

# %%
mod.evaluate(x_test, y_test)
# Out:
# 37/37 [==============================] - 0s 3ms/step - loss: 6.5703 - mean_absolute_error: 6.5703
# [6.570342540740967, 6.570342540740967]

# %%
plt.imshow(train_generator[0][0][12])
